# %% [markdown]
# <a href="https://colab.research.google.com/github/Akbar-fitriawan/Matplotlib-tutorial/blob/main/pandas_coba_manipulasi_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Data

# %%
data_kategori = {
    'kategori_id':np.array([i for i in range(1,5)]),
    'ketagori':np.array(['makana','minuman','tambahan','kudapan']),
}

data_produk = {
    'kategori_id':np.array([1,1,1,2,2,2,1,3,2,3]),
    'produk':np.array([
        'Soto Ayam',
        'Nasi Goreng Seafood',
        'Sate Kambing',
        'Limun Soda',
        'Kopi Susu',
        'Air Mineral',
        'Bakso Sapi',
        'Tempe Bacem',
        'Es Teh Manis',
        'Kerupuk',
        ]),
}

# %% [markdown]
# # Operasi

# %%
kategori = pd.DataFrame(data_kategori)
produk = pd.DataFrame(data_produk)
gabung_table = pd.merge(produk,kategori, on='kategori_id')
gabung_table_outer = pd.merge(produk,kategori, on='kategori_id', how='outer')

# %% [markdown]
# # Sorting

# %%
urutkan = produk.sort_values(by='produk')
# urutkan = produk.sort_values(by='produk', ascending=False) # di balik urutannya
# urutkan_berdasarkan_index = produk.sort_index() # default nya gitu

# %%
df1 = pd.DataFrame([4,5,2,7,1,8], columns=['nilai'])
df1['ranking'] = df1['nilai'].rank()
print(df1)
# Out:
#    nilai  ranking
# 0      4      3.0
# 1      5      4.0
# 2      2      2.0
# 3      7      5.0
# 4      1      1.0
# 5      8      6.0

# %% [markdown]
# # output

# %%
print(kategori, '\n') # Data kategori
print(produk, '\n') # Data produk
print(gabung_table, '\n') # merge join
print(gabung_table_outer,'\n') # merge outer yang data Nan juga muncul
print(urutkan,'\n')
# Out:
#    kategori_id  ketagori
# 0            1    makana
# 1            2   minuman
# 2            3  tambahan
# 3            4   kudapan
#
#    kategori_id               produk
# 0            1            Soto Ayam
# 1            1  Nasi Goreng Seafood
# 2            1         Sate Kambing
# 3            2           Limun Soda
# 4            2            Kopi Susu
# 5            2          Air Mineral
# 6            1           Bakso Sapi
# 7            3          Tempe Bacem
# 8            2         Es Teh Manis
# 9            3              Kerupuk
#
#    kategori_id               produk  ketagori
# 0            1            Soto Ayam    makana
# 1            1  Nasi Goreng Seafood    makana
# 2            1         Sate Kambing    makana
# 3            1           Bakso Sapi    makana
# 4            2           Limun Soda   minuman
# 5            2            Kopi Susu   minuman
# 6            2          Air Mineral   minuman
# 7            2         Es Teh Manis   minuman
# 8            3          Tempe Bacem  tambahan
# 9            3              Kerupuk  tambahan
#
#     kategori_id               produk  ketagori
# 0             1            Soto Ayam    makana
# 1             1  Nasi Goreng Seafood    makana
# 2             1         Sate Kambing    makana
# 3             1           Bakso Sapi    makana
# 4             2           Limun Soda   minuman
# 5             2            Kopi Susu   minuman
# 6             2          Air Mineral   minuman
# 7             2         Es Teh Manis   minuman
# 8             3          Tempe Bacem  tambahan
# 9             3              Kerupuk  tambahan
# 10            4                  NaN   kudapan
#
#    kategori_id               produk
# 5            2          Air Mineral
# 6            1           Bakso Sapi
# 8            2         Es Teh Manis
# 9            3              Kerupuk
# 4            2            Kopi Susu
# 3            2           Limun Soda
# 1            1  Nasi Goreng Seafood
# 2            1         Sate Kambing
# 0            1            Soto Ayam
# 7            3          Tempe Bacem

# %% [markdown]
# # Binning 'Pecah data jadi bin(kecil)'

# %%
kelompok_usia = np.array([1,12,25,45,65])
kelompok_usia_label = np.array(['anak-anak','remaja','dewasa','lanjut usia'])
jumlah_data = 30
responden = np.array([i + np.random.randint(1,67) for i in range(jumlah_data)])

print(kelompok_usia)
print(kelompok_usia_label)
print(responden)
# Out:
# [ 1 12 25 45 65]
# ['anak-anak' 'remaja' 'dewasa' 'lanjut usia']
# [26 23  7 30 28 69 39 46 66 49 49 77 36 79 54 67 56 58 49 39 70 27 38 69
#  48 72 86 64 67 78]

# %%
binning = pd.cut(responden, kelompok_usia, labels=kelompok_usia_label) # di bagi menjadi kecil berdasarkan label

data = {
    'kategori':binning,
    'usia':responden,
}


data_frame = pd.DataFrame(data).dropna()

print(binning, '\n')
print(data_frame,'\n')
pd.value_counts(binning)
data_frame.head(5)
# Out:
# ['dewasa', 'remaja', 'anak-anak', 'dewasa', 'dewasa', ..., NaN, NaN, 'lanjut usia', NaN, NaN]
# Length: 30
# Categories (4, object): ['anak-anak' < 'remaja' < 'dewasa' < 'lanjut usia']
#
#        kategori  usia
# 0        dewasa    26
# 1        remaja    23
# 2     anak-anak     7
# 3        dewasa    30
# 4        dewasa    28
# 6        dewasa    39
# 7   lanjut usia    46
# 9   lanjut usia    49
# 10  lanjut usia    49
# 12       dewasa    36
# 14  lanjut usia    54
# 16  lanjut usia    56
# 17  lanjut usia    58
# 18  lanjut usia    49
# 19       dewasa    39
# 21       dewasa    27
# 22       dewasa    38
# 24  lanjut usia    48
# 27  lanjut usia    64
#     kategori  usia
# 0     dewasa    26
# 1     remaja    23
# 2  anak-anak     7
# 3     dewasa    30
# 4     dewasa    28

# %% [markdown]
# # Agregat sum,count,unique,mean,min max,median,std

# %%
df1 = pd.read_csv('/penerbangan1.csv', names=['tanggal','flight','asal','tujuan','penumpang','durasi'])
df1.head(5)
# Out:
#       tanggal flight      asal       tujuan  penumpang  durasi
# 0  2019-01-20   G201   Jakarta         Bali        136      50
# 1  2019-01-20   G014     Medan      Jakarta         44     120
# 2  2019-01-20   B046   Jakarta   Yogyakarta        155      50
# 3  2019-01-20   G100   Jakarta     Surabaya         90      60
# 4  2019-01-20   G781   Jakarta   Yogyakarta        158      50

# %%
perhari = df1.groupby('tanggal')
perhari.sum()
# Out:
# <ipython-input-104-e0d5e6b9460a>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   perhari.sum()
#             penumpang  durasi
# tanggal
# 2019-01-20        914     540
# 2019-01-21       1068     550
# 2019-01-22       1042     590
# 2019-01-23       1082     680

# %%
perhari_tujuan = df1.groupby(['tujuan','tanggal'])
perhari_tujuan.sum()
# Out:
# <ipython-input-105-ecaf4d4d395a>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   perhari_tujuan.sum()
#                         penumpang  durasi
# tujuan      tanggal
#  Bali       2019-01-20        234     140
#             2019-01-22        255      90
#             2019-01-23        225     120
#  Jakarta    2019-01-20         44     120
#             2019-01-21        650     310
#             2019-01-22        231     230
#             2019-01-23        582     460
#  Makassar   2019-01-21        149     120
#  Medan      2019-01-20        233     120
#             2019-01-22        169     120
#  Surabaya   2019-01-20         90      60
#             2019-01-21        269     120
#  Yogyakarta 2019-01-20        313     100
#             2019-01-22        387     150
#             2019-01-23        275     100

# %%
perkota = df1['penumpang'].groupby(df1['asal'])
perkota.sum()
# Out:
# asal
#  Bali           226
#  Bandung         98
#  Jakarta       2501
#  Makassar       268
#  Medan          417
#  Surabaya       430
#  Yogyakarta     166
# Name: penumpang, dtype: int64

# %% [markdown]
# # Pivot Table

# %%
df1.pivot_table(values='penumpang', index='tanggal', columns='tujuan') # tujuan jadi sumbu x sedangkan kolom penumpang jadi nilai yang di tampilkan
df1.pivot_table(values='penumpang', index='tanggal', columns='tujuan', fill_value=0) # fill_value = merubah data Nan(not a number) jadi 0
df1.pivot_table(values='penumpang', index='tanggal', columns='tujuan', fill_value=0, aggfunc='sum') # agregat fungsi
# Out:
# tujuan       Bali   Jakarta   Makassar   Medan   Surabaya   Yogyakarta
# tanggal
# 2019-01-20    234        44          0     233         90          313
# 2019-01-21      0       650        149       0        269            0
# 2019-01-22    255       231          0     169          0          387
# 2019-01-23    225       582          0       0          0          275
